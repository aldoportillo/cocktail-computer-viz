# %% [markdown]
# # Cocktail Classifier Computer Viz

# %%
testing = 5

# %%
i = 0

while i <= 5:
    print(i)
    i = 1 + i;
# Out:
# 0
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# Open this file in [Google Collab](https://colab.research.google.com/github/aldoportillo/cocktail-computer-viz/blob/aldoportillo/Welcome.ipynb]
